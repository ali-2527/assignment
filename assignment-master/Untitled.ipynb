# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import csv
img1 = cv2.imread("one.jfif",0)
img2 = cv2.imread("two.jfif",0)
img3 = cv2.imread("three.jfif",0)
img4 = cv2.imread("four.jfif",0)
img5 = cv2.imread("five.jfif",0)
img6 = cv2.imread("six.jfif",0)
img7 = cv2.imread("seven.jfif",0)
img8 = cv2.imread("eight.jfif",0)
img9 = cv2.imread("nine.jfif",0)
img10 = cv2.imread("ten.jfif",0)
img11 = cv2.imread("eleven.jpg",0)
img12 = cv2.imread("twelve.jpg",0)
img13 = cv2.imread("thirteen.jpg",0)
img14 = cv2.imread("fourteen.jpg",0)
img15 = cv2.imread("fifteen.jpg",0)
img16 = cv2.imread("sixteen.jpg",0)
img17 = cv2.imread("seventeen.jpg",0)
img18 = cv2.imread("eighteen.jpg",0)
img19 = cv2.imread("ninteen.jpg",0)
img20 = cv2.imread("twenty.jpg",0)
arr1 = np.array(img1)
arr2 = np.array(img2)
arr3 = np.array(img3)
arr4 = np.array(img4)
arr5 = np.array(img5)
arr6 = np.array(img6)
arr7 = np.array(img7)
arr8 = np.array(img8)
arr9 = np.array(img9)
arr10 = np.array(img10)
arr11 = np.array(img11)
arr12 = np.array(img12)
arr13 = np.array(img13)
arr14 = np.array(img14)
arr15 = np.array(img15)
arr16 = np.array(img16)
arr17 = np.array(img17)
arr18 = np.array(img18)
arr19 = np.array(img19)
arr20 = np.array(img20)
new = [[arr1],[arr2],[arr3],[arr4],[arr5],[arr6],[arr7],[arr8],[arr9],[arr10],[arr11],[arr12],[arr13],[arr14],[arr15],[arr16],[arr17],[arr18],[arr19],[arr20]]
new = np.array(new)
new
with open("test.csv" , "w" , newline = "") as f:
    test = csv.reader(f, delimiter=",")

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\student.desktop-vln6bdn\anaconda3\lib\site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\student.desktop-vln6bdn\anaconda3\lib\site-packages (from pandas) (1.16.4)
# Requirement already satisfied: pytz>=2011k in c:\users\student.desktop-vln6bdn\anaconda3\lib\site-packages (from pandas) (2019.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\student.desktop-vln6bdn\anaconda3\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\student.desktop-vln6bdn\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
pd.DataFrame(new).to_csv("test.csv")

# %%
new
# Out:
# array([[array([[113, 114, 114, ..., 113, 113, 112],
#        [113, 114, 114, ..., 113, 113, 113],
#        [113, 114, 114, ..., 114, 113, 113],
#        ...,
#        [113, 114, 114, ..., 114, 113, 113],
#        [113, 114, 114, ..., 113, 113, 113],
#        [113, 114, 114, ..., 113, 113, 112]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[238, 238, 238, ..., 238, 238, 238],
#        [238, 238, 238, ..., 238, 238, 238],
#        [238, 238, 238, ..., 238, 238, 238],
#        ...,
#        [238, 238, 238, ..., 238, 238, 238],
#        [238, 238, 238, ..., 238, 238, 238],
#        [238, 238, 238, ..., 238, 238, 238]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254]], dtype=uint8)],
#        [array([[246, 246, 246, ..., 246, 246, 246],
#        [246, 246, 246, ..., 246, 246, 246],
#        [246, 246, 246, ..., 246, 246, 246],
#        ...,
#        [246, 246, 246, ..., 246, 246, 246],
#        [246, 246, 246, ..., 246, 246, 246],
#        [246, 246, 246, ..., 246, 246, 246]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [250, 254, 255, ..., 255, 255, 255],
#        [255, 254, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [254, 254, 254, ..., 254, 254, 254],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#        [array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)]], dtype=object)
